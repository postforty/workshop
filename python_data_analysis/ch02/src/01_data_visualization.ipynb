# %% [markdown]
# ## 📊 Python 데이터 시각화 모듈 (Top 3)
#
# ### 1. Matplotlib
#
# Matplotlib은 Python 데이터 시각화의 **기반이자 표준**으로 간주됩니다.
#
# * **특징:**
#     * **강력한 제어:** 거의 모든 시각적 요소를 세밀하게 (축, 제목, 레이블, 선 스타일 등) 사용자 정의하고 제어할 수 있는 **저수준 API**를 제공합니다.
#     * **다양성:** 기본적인 선 그래프, 산점도부터 히스토그램, 3D 플롯, 애니메이션까지 다양한 정적, 동적 시각화를 지원합니다.
#     * **역사 및 생태계:** 가장 오래되었으며 가장 큰 사용자 커뮤니티와 방대한 자료를 보유하고 있어, 많은 다른 라이브러리들이 Matplotlib을 기반으로 구축되어 있습니다.
# * **용도:** 기본적인 플롯 생성, **출판 품질의 맞춤형** 정적 그래프 제작, 다른 라이브러리(예: Pandas)의 시각화 백엔드로 활용하는 경우에 적합합니다.
#
# ---
#
# ### 2. Seaborn
#
# Seaborn은 Matplotlib을 기반으로 구축되었으며, **통계적 데이터 시각화**에 특화되어 있습니다.
#
# * **특징:**
#     * **통계 지향:** 데이터셋의 통계적 관계를 시각화하는 데 중점을 둔 다양한 **고수준 함수**를 제공합니다 (예: $lmplot$, $pairplot$, $boxplot$).
#     * **미적 요소:** **기본적으로 아름답고 전문적인** 디자인과 색상 팔레트가 적용되어, 적은 코드로도 높은 품질의 시각화 결과를 얻을 수 있습니다.
#     * **데이터 구조:** Pandas DataFrame과 매우 잘 통합되어 있어, 데이터를 특정 형식으로 전처리할 필요 없이 쉽게 플롯을 생성할 수 있습니다.
# * **용도:** 통계 분석 결과의 시각화, **데이터 분포와 변수 간의 관계**를 빠르고 효과적으로 탐색할 때 최적입니다.
#
# ---
#
# ### 3. Plotly
#
# Plotly는 **인터랙티브 웹 기반 시각화**를 생성하는 데 강력한 모듈입니다.
#
# * **특징:**
#     * **대화형(Interactive):** 생성된 그래프는 웹 브라우저 기반으로 동작하며, **확대/축소(Zooming)**, **마우스 오버 정보 표시(Hover)**, 데이터 필터링 등의 상호작용 기능을 기본적으로 제공합니다.
#     * **범용성:** Python 외에도 R, Julia 등 다양한 언어를 지원하며, 대시보드 애플리케이션(Dash) 개발에 사용될 수 있습니다.
#     * **다양한 형식:** 과학적 차트(Contour, Heatmaps)부터 금융 차트(Candlestick), 지도 시각화까지 광범위한 형식을 지원합니다.
# * **용도:** 웹 기반 **대시보드** 구축, **사용자와의 상호작용**이 필요한 데이터 분석 리포트, 대규모 데이터셋의 탐색적 시각화에 매우 유용합니다.
#
# ---
#
# ### 🚀 요약
#
# | 모듈 | 주된 목적 | 난이도 및 제어 | 출력 형식 |
# | :--- | :--- | :--- | :--- |
# | **Matplotlib** | 정밀한 사용자 정의 정적 그래프 | 저수준 API, **최대 제어** | 정적 (이미지 파일) |
# | **Seaborn** | 통계적 데이터 관계 탐색 | 고수준 API, **빠른 분석** | 정적 (Matplotlib 기반) |
# | **Plotly** | 대화형 웹 기반 시각화 | 고수준 API, 웹 통합 | **대화형** (HTML, 웹) |
#
# ※ 저수준 API, 고수준 API 구분은 추상화(Abstraction)의 정도

# %% [markdown]
# ---

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# > 여기에서 사용한 예제는 "**Matplotlib Tutorial - 파이썬으로 데이터 시각화하기** (<https://wikidocs.net/book/5011>)"를 참고하였습니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4]) # * y값
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) # * x-y 값
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) # x-y 값
plt.xlabel('X-Label') # * 레이블 표시
plt.ylabel('Y-Label')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], label='Price') # x-y 값
plt.xlabel('X-Label') # 레이블 표시
plt.ylabel('Y-Label')
plt.legend() # * 범례 표시
# plt.legend(loc='lower right') # * 범례 표시 + 위치 설정
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2)

plt.show()

# %% [markdown]
# ### 🎨 Matplotlib 시각화 설정 단축 코드 정리
#
# #### 1. 색상 (Colors)
#
# | Character | Color |
# | :---: | :--- |
# | `b` | blue (파란색) |
# | `g` | green (초록색) |
# | `r` | red (빨간색) |
# | `c` | cyan (청록색) |
# | `m` | magenta (자홍색) |
# | `y` | yellow (노란색) |
# | `k` | black (검은색) |
# | `w` | white (흰색) |
#
# #### 2. 선 스타일 (Line Styles)
#
# | Character | Description |
# | :---: | :--- |
# | `-` | solid line style (실선 스타일) |
# | `--` | dashed line style (대시선 스타일) |
# | `-.` | dash-dot line style (대시-점선 스타일) |
# | `:` | dotted line style (점선 스타일) |
#
# #### 3. 마커 (Markers)
#
# | Character | Description |
# | :---: | :--- |
# | `.` | point marker (점 마커) |
# | `,` | pixel marker (픽셀 마커) |
# | `o` | circle marker (원 마커) |
# | `v` | triangle\_down marker (역삼각형 마커) |
# | `^` | triangle\_up marker (삼각형 마커) |
# | `<` | triangle\_left marker (왼쪽 삼각형 마커) |
# | `>` | triangle\_right marker (오른쪽 삼각형 마커) |
# | `1` | tri\_down marker (아래쪽 삼각 마커) |
# | `2` | tri\_up marker (위쪽 삼각 마커) |
# | `3` | tri\_left marker (왼쪽 삼각 마커) |
# | `4` | tri\_right marker (오른쪽 삼각 마커) |
# | `s` | square marker (정사각형 마커) |
# | `p` | pentagon marker (오각형 마커) |
# | `*` | star marker (별 마커) |
# | `h` | hexagon1 marker (육각형1 마커) |
# | `H` | hexagon2 marker (육각형2 마커) |
# | `+` | plus marker (플러스 마커) |
# | `x` | x marker (엑스 마커) |
# | `D` | diamond marker (다이아몬드 마커) |
# | `d` | thin\_diamond marker (얇은 다이아몬드 마커) |
# | `\|` | vline marker (수직선 마커) |
# | `_` | hline marker (수평선 마커) |
#
# **색상-마커-선 스타일** 순서로 결합(예: `r--o`는 빨간색-대시선-원 마커)

# %%
# 마커 지정
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'o-', label='Price')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], 'v-', label='Demand')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2)

plt.show()

# %%
# 선 종류 지정
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label='solid')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label='dashed')
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label='dotted')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label='dashdot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout()
plt.show()

# %%
# 색상 지정
plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### 막대 그래프

# %%
x = [0, 1, 2]
y = [100, 400, 900]
years = ['2023', '2024', '2025']
colors = ['r', 'g', 'b']

plt.bar(x, y, color=colors, tick_label=years)

plt.show()

# %% [markdown]
# ### 수평 막대 그래프

# %%
x = [100, 400, 900]
y = [0, 1, 2]
years = ['2023', '2024', '2025']
colors = ['r', 'g', 'b']

plt.barh(y, x, color=colors, tick_label=years)

plt.show()

# %%
import numpy as np

# 0과 1 사이의 난수 50개 1차원 NumPy 배열 생성
np.random.seed(0)
np.random.rand(50)
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#        0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#        0.79172504, 0.52889492, 0.56804456, 0.92559664, 0.07103606,
#        0.0871293 , 0.0202184 , 0.83261985, 0.77815675, 0.87001215,
#        0.97861834, 0.79915856, 0.46147936, 0.78052918, 0.11827443,
#        0.63992102, 0.14335329, 0.94466892, 0.52184832, 0.41466194,
#        0.26455561, 0.77423369, 0.45615033, 0.56843395, 0.0187898 ,
#        0.6176355 , 0.61209572, 0.616934  , 0.94374808, 0.6818203 ,
#        0.3595079 , 0.43703195, 0.6976312 , 0.06022547, 0.66676672,
#        0.67063787, 0.21038256, 0.1289263 , 0.31542835, 0.36371077])

# %% [markdown]
# ### 산점도 (Scatter plot)

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2 # 0과 1사이 난수를 0과 30 사이로 확장(Scaling)한 후 연산 결과로 나온 배열의 모든 요소에 제곱 적용
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='Spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# ### 3차원 산점도 (3D Scatter plot)

# %%
from mpl_toolkits.mplot3d import Axes3D

n = 300
xmin, xmax, ymin, ymax, zmin, zmax = 0, 20, 0, 20, 0, 50
cmin, cmax = 0, 2

xs = np.array([(xmax - xmin) * np.random.random_sample() + xmin for i in range(n)])
ys = np.array([(ymax - ymin) * np.random.random_sample() + ymin for i in range(n)])
zs = np.array([(zmax - zmin) * np.random.random_sample() + zmin for i in range(n)])
color = np.array([(cmax - cmin) * np.random.random_sample() + cmin for i in range(n)])

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c=color, marker='o', s=15, cmap='Greens')

plt.show()

# %%
weight = [68, 81, 64, 56, 78, 74, 61, 77, 66, 68, 59, 71, 80, 59, 67, 81, 69, 73, 69, 74, 70, 65]
len(weight)
# Out:
# 22

# %% [markdown]
# ### 히스토그램 (Histogram)
#
# 히스토그램 (Histogram)은 도수분포표를 그래프로 나타낸 것으로서, 가로축은 계급, 세로축은 도수 (횟수나 개수 등)를 나타냅니다.

# %%
plt.hist(weight, label='bins=10') # bins 기본값은 10개
plt.hist(weight, bins=30, label='bins=30')
plt.legend()

plt.show()

# %% [markdown]
# ### 파이 차트 (Pie chart, 원 그래프)

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]

plt.pie(ratio, 
    labels=labels, 
    autopct='%.1f%%', 
    counterclock=False, # * 시계 방향 순서로 부채꼴 영역이 표시
    explode=explode) # * 중심에서 벗어나는 정도 설정
        
plt.show()

# %%
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.pie(ratio, 
    labels=labels, 
    autopct='%.1f%%', 
    startangle=260, 
    counterclock=False, 
    colors=colors,
    wedgeprops=wedgeprops) # wedgeprops는 부채꼴 영역의 스타일 설정
plt.show()

# %% [markdown]
# ### 히트맵

# %%
arr = np.random.standard_normal((30, 40))

plt.matshow(arr)
plt.colorbar(shrink=0.8, aspect=10)
plt.clim(-1.0, 1.0) # 색상의 범위를 -1.0 ~ 1.0 으로 지정한 히트맵
# plt.clim(-3.0, 3.0)

plt.show()

# %% [markdown]
# ### 두 종류의 그래프 그리기

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(2020, 2026)
y1 = np.array([1, 3, 7, 5, 9, 7])
y2 = np.array([1, 3, 5, 7, 9, 11])

# 3. 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y1, '-s', color='green', markersize=7, linewidth=5, alpha=0.7, label='Price')
ax1.set_ylim(0, 18)
ax1.set_xlabel('Year')
ax1.set_ylabel('Price')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(x, y2, color='deeppink', label='Demand', alpha=0.7, width=0.7)
ax2.set_ylim(0, 18)
ax2.set_ylabel(r'Demand')
ax2.tick_params(axis='y', direction='in')

ax1.set_zorder(ax2.get_zorder() + 10)
ax1.patch.set_visible(False)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()

# %% [markdown]
# ### 박스 플롯 (Box plot)
#
# 일반적으로 박스 플롯은 전체 데이터로부터 얻어진 아래의 다섯 가지 요약 수치를 사용해서 그려집니다.
#
# + 최소값
# + 제 1사분위 수 (Q1)
# + 제 2사분위 수 또는 중위수 (Q2)
# + 제 3사분위 수 (Q3)
# + 최대값

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
np.random.seed(0)
data_a = np.random.normal(0, 2.0, 1000)
data_b = np.random.normal(-3.0, 1.5, 500)
data_c = np.random.normal(1.2, 1.5, 1500)

# 3. 그래프 그리기
fig, ax = plt.subplots()

ax.boxplot([data_a, data_b, data_c], notch=True, whis=2.5)
ax.set_ylim(-10.0, 10.0)
ax.set_xlabel('Data Type')
ax.set_ylabel('Value')

plt.show()

# %% [markdown]
# ### 바이올린 플롯 (Violin plot)
#
# 데이터의 분포와 범위를 한눈에 보기 쉽게 나타내는 그래프 형식입니다.
#
# 박스 플롯 (Box plot)과 비슷하지만 더 실제에 가까운 분포를 알 수 있다는 장점이 있습니다.

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
np.random.seed(0)
data_a = np.random.normal(0, 2.0, 1000)
data_b = np.random.normal(-3.0, 1.5, 500)
data_c = np.random.normal(1.2, 1.5, 1500)

# 3. 그래프 그리기
fig, ax = plt.subplots()

violin = ax.violinplot([data_a, data_b, data_c], showmeans=True)
ax.set_ylim(-10.0, 10.0)
ax.set_xticks(np.arange(1, 4))
ax.set_xticklabels(['A', 'B', 'C'])
ax.set_xlabel('Data Type')
ax.set_ylabel('Value')

violin['bodies'][0].set_facecolor('blue')
violin['bodies'][1].set_facecolor('red')
violin['bodies'][2].set_facecolor('green')

violin['cbars'].set_edgecolor('gray')
violin['cmaxes'].set_edgecolor('gray')
violin['cmins'].set_edgecolor('gray')
violin['cmeans'].set_edgecolor('gray')

plt.show()
